# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key
from config import g_key

# %%
# Generate 2,000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['lompoc', 'jamestown', 'bredasdorp', 'tumannyy', 'ushuaia', 'vaini', 'punta arenas', 'mataura', 'tasiilaq', 'carnarvon'] Generate 733

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

    

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lompoc
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | juan lacaze
# Processing Record 12 of Set 1 | mahebourg
# Processing Record 13 of Set 1 | whitehorse
# Processing Record 14 of Set 1 | pontianak
# Processing Record 15 of Set 1 | sungairaya
# Processing Record 16 of Set 1 | nago
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | fortuna
# Processing Record 20 of Set 1 | kavieng
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | coquimbo
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | chapais
# Processing Record 30 of Set 1 | kruisfontein
# Processing Record 31 of Set 1 | lisakovsk
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | hovd
# Processing Record 34 of Set 1 | yar-sale
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | coahuayana
# Processing Record 38 of Set 1 | kawana waters
# City not found. Skipping...
# Processing Record 39 of Set 1 | taoudenni
# Processing Record 40 of Set 1 | faanui
# Processing Record 41 of Set 1 | skjaerhollen
# City not found. Skipping...
# Processing Record 42 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 44 of Set 1 | bambous virieux
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | mehamn
# Processing Record 47 of Set 1 | port moresby
# Processing Record 48 of Set 1 | fiumicino
# Processing Record 49 of Set 1 | bolshoy uluy
# City not found. Skipping...
# Processing Record 50 of Set 1 | victoria
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | zhuhai
# Processing Record 3 of Set 2 | pacific grove
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | korla
# Processing Record 6 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 2 | sept-iles
# Processing Record 8 of Set 2 | lagos
# Processing Record 9 of Set 2 | maputo
# Processing Record 10 of Set 2 | ati
# Processing Record 11 of Set 2 | riwaka
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | coihaique
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | jumla
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | norman wells
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 2 | northam
# Processing Record 23 of Set 2 | nome
# Processing Record 24 of Set 2 | tuatapere
# Processing Record 25 of Set 2 | kahului
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | eureka
# Processing Record 28 of Set 2 | bundaberg
# Processing Record 29 of Set 2 | lagoa
# Processing Record 30 of Set 2 | neyshabur
# Processing Record 31 of Set 2 | beringovskiy
# Processing Record 32 of Set 2 | mandera
# Processing Record 33 of Set 2 | puerto leguizamo
# Processing Record 34 of Set 2 | melilla
# Processing Record 35 of Set 2 | saskylakh
# Processing Record 36 of Set 2 | esperance
# Processing Record 37 of Set 2 | busselton
# Processing Record 38 of Set 2 | saldanha
# Processing Record 39 of Set 2 | qaanaaq
# Processing Record 40 of Set 2 | severo-kurilsk
# Processing Record 41 of Set 2 | bady bassitt
# Processing Record 42 of Set 2 | seminole
# Processing Record 43 of Set 2 | charagua
# Processing Record 44 of Set 2 | opuwo
# Processing Record 45 of Set 2 | goure
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | maldonado
# Processing Record 48 of Set 2 | grimstad
# Processing Record 49 of Set 2 | egvekinot
# Processing Record 50 of Set 2 | klaksvik
# Processing Record 1 of Set 3 | sernur
# Processing Record 2 of Set 3 | haines junction
# Processing Record 3 of Set 3 | qaqortoq
# Processing Record 4 of Set 3 | nizhnevartovsk
# Processing Record 5 of Set 3 | grindavik
# Processing Record 6 of Set 3 | mehran
# Processing Record 7 of Set 3 | burica
# City not found. Skipping...
# Processing Record 8 of Set 3 | sambava
# Processing Record 9 of Set 3 | cherskiy
# Processing Record 10 of Set 3 | soavinandriana
# Processing Record 11 of Set 3 | rassvet
# Processing Record 12 of Set 3 | bethel
# Processing Record 13 of Set 3 | chuy
# Processing Record 14 of Set 3 | broken hill
# Processing Record 15 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 16 of Set 3 | ponta do sol
# Processing Record 17 of Set 3 | hervey bay
# Processing Record 18 of Set 3 | aketi
# Processing Record 19 of Set 3 | port blair
# Processing Record 20 of Set 3 | linxia
# Processing Record 21 of Set 3 | puerto ayora
# Processing Record 22 of Set 3 | nouakchott
# Processing Record 23 of Set 3 | lahij
# Processing Record 24 of Set 3 | aykhal
# Processing Record 25 of Set 3 | gigmoto
# Processing Record 26 of Set 3 | cotonou
# Processing Record 27 of Set 3 | batamshinskiy
# Processing Record 28 of Set 3 | asau
# Processing Record 29 of Set 3 | canchungo
# Processing Record 30 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 3 | hoquiam
# Processing Record 32 of Set 3 | ambon
# Processing Record 33 of Set 3 | baiao
# Processing Record 34 of Set 3 | seabra
# Processing Record 35 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 3 | yulara
# Processing Record 38 of Set 3 | moerai
# Processing Record 39 of Set 3 | poltavka
# Processing Record 40 of Set 3 | mount isa
# Processing Record 41 of Set 3 | rawson
# Processing Record 42 of Set 3 | dukat
# Processing Record 43 of Set 3 | sur
# Processing Record 44 of Set 3 | mazagao
# Processing Record 45 of Set 3 | oriximina
# Processing Record 46 of Set 3 | adrar
# Processing Record 47 of Set 3 | icod de los vinos
# Processing Record 48 of Set 3 | staroutkinsk
# Processing Record 49 of Set 3 | port augusta
# Processing Record 50 of Set 3 | pangnirtung
# Processing Record 1 of Set 4 | chumikan
# Processing Record 2 of Set 4 | ngunguru
# Processing Record 3 of Set 4 | la paz
# Processing Record 4 of Set 4 | east london
# Processing Record 5 of Set 4 | rio gallegos
# Processing Record 6 of Set 4 | saint-pierre
# Processing Record 7 of Set 4 | hofn
# Processing Record 8 of Set 4 | trairi
# Processing Record 9 of Set 4 | tarbagatay
# Processing Record 10 of Set 4 | cockburn town
# Processing Record 11 of Set 4 | ahipara
# Processing Record 12 of Set 4 | marsh harbour
# Processing Record 13 of Set 4 | sorong
# Processing Record 14 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 4 | chokurdakh
# Processing Record 16 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 4 | tiksi
# Processing Record 18 of Set 4 | kavaratti
# Processing Record 19 of Set 4 | torbay
# Processing Record 20 of Set 4 | nikolskoye
# Processing Record 21 of Set 4 | sorland
# Processing Record 22 of Set 4 | cidreira
# Processing Record 23 of Set 4 | verkhnevilyuysk
# Processing Record 24 of Set 4 | port macquarie
# Processing Record 25 of Set 4 | narsaq
# Processing Record 26 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 27 of Set 4 | half moon bay
# Processing Record 28 of Set 4 | kapaa
# Processing Record 29 of Set 4 | ostrovnoy
# Processing Record 30 of Set 4 | provideniya
# Processing Record 31 of Set 4 | tuktoyaktuk
# Processing Record 32 of Set 4 | noumea
# Processing Record 33 of Set 4 | plettenberg bay
# Processing Record 34 of Set 4 | broome
# Processing Record 35 of Set 4 | castro
# Processing Record 36 of Set 4 | charters towers
# Processing Record 37 of Set 4 | tchibanga
# Processing Record 38 of Set 4 | aracaju
# Processing Record 39 of Set 4 | wenatchee
# Processing Record 40 of Set 4 | scalloway
# City not found. Skipping...
# Processing Record 41 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 4 | mashhad
# Processing Record 43 of Set 4 | santa rosalia
# Processing Record 44 of Set 4 | saint-joseph
# Processing Record 45 of Set 4 | vegachi
# Processing Record 46 of Set 4 | griffith
# Processing Record 47 of Set 4 | tiarei
# Processing Record 48 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 4 | kodiak
# Processing Record 50 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 5 | namibe
# Processing Record 2 of Set 5 | siva
# Processing Record 3 of Set 5 | datong
# Processing Record 4 of Set 5 | kushmurun
# Processing Record 5 of Set 5 | khatanga
# Processing Record 6 of Set 5 | labuhan
# Processing Record 7 of Set 5 | geraldton
# Processing Record 8 of Set 5 | yagodnoye
# Processing Record 9 of Set 5 | husavik
# Processing Record 10 of Set 5 | casas grandes
# Processing Record 11 of Set 5 | kiunga
# Processing Record 12 of Set 5 | zambezi
# Processing Record 13 of Set 5 | bengkulu
# Processing Record 14 of Set 5 | meadow lake
# Processing Record 15 of Set 5 | hasaki
# Processing Record 16 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 17 of Set 5 | iskilip
# Processing Record 18 of Set 5 | santa maria da boa vista
# Processing Record 19 of Set 5 | morgan city
# Processing Record 20 of Set 5 | mucurapo
# Processing Record 21 of Set 5 | katherine
# Processing Record 22 of Set 5 | alugan
# Processing Record 23 of Set 5 | ucluelet
# Processing Record 24 of Set 5 | lebu
# Processing Record 25 of Set 5 | patacamaya
# Processing Record 26 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 5 | airai
# Processing Record 28 of Set 5 | necochea
# Processing Record 29 of Set 5 | steamboat springs
# Processing Record 30 of Set 5 | mumford
# Processing Record 31 of Set 5 | hithadhoo
# Processing Record 32 of Set 5 | sahrak
# City not found. Skipping...
# Processing Record 33 of Set 5 | jiexiu
# Processing Record 34 of Set 5 | camalu
# Processing Record 35 of Set 5 | gizo
# Processing Record 36 of Set 5 | trat
# Processing Record 37 of Set 5 | sabratah
# Processing Record 38 of Set 5 | miri
# Processing Record 39 of Set 5 | puerto escondido
# Processing Record 40 of Set 5 | thompson
# Processing Record 41 of Set 5 | moses lake
# Processing Record 42 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 5 | santa maria
# Processing Record 44 of Set 5 | prachuap khiri khan
# Processing Record 45 of Set 5 | srednekolymsk
# Processing Record 46 of Set 5 | takoradi
# Processing Record 47 of Set 5 | anloga
# Processing Record 48 of Set 5 | pevek
# Processing Record 49 of Set 5 | lampitak
# Processing Record 50 of Set 5 | sioux lookout
# Processing Record 1 of Set 6 | vila franca do campo
# Processing Record 2 of Set 6 | manjacaze
# Processing Record 3 of Set 6 | mecca
# Processing Record 4 of Set 6 | taltal
# Processing Record 5 of Set 6 | kumba
# Processing Record 6 of Set 6 | polovinnoye
# Processing Record 7 of Set 6 | jhikargachha
# City not found. Skipping...
# Processing Record 8 of Set 6 | marystown
# Processing Record 9 of Set 6 | marsa matruh
# Processing Record 10 of Set 6 | kargasok
# Processing Record 11 of Set 6 | addanki
# Processing Record 12 of Set 6 | lafiagi
# Processing Record 13 of Set 6 | raga
# Processing Record 14 of Set 6 | pisco
# Processing Record 15 of Set 6 | baghdad
# Processing Record 16 of Set 6 | kharp
# Processing Record 17 of Set 6 | rosetta
# Processing Record 18 of Set 6 | vila velha
# Processing Record 19 of Set 6 | imeni babushkina
# Processing Record 20 of Set 6 | puerto ayacucho
# Processing Record 21 of Set 6 | north myrtle beach
# Processing Record 22 of Set 6 | tsiroanomandidy
# Processing Record 23 of Set 6 | manado
# Processing Record 24 of Set 6 | staroaleyskoye
# Processing Record 25 of Set 6 | ivybridge
# Processing Record 26 of Set 6 | abu dhabi
# Processing Record 27 of Set 6 | te anau
# Processing Record 28 of Set 6 | georgetown
# Processing Record 29 of Set 6 | phrai bung
# City not found. Skipping...
# Processing Record 30 of Set 6 | surazh
# Processing Record 31 of Set 6 | alta floresta
# Processing Record 32 of Set 6 | la ronge
# Processing Record 33 of Set 6 | longyearbyen
# Processing Record 34 of Set 6 | moultrie
# Processing Record 35 of Set 6 | tessalit
# Processing Record 36 of Set 6 | mount gambier
# Processing Record 37 of Set 6 | xai-xai
# Processing Record 38 of Set 6 | bilma
# Processing Record 39 of Set 6 | kurunegala
# Processing Record 40 of Set 6 | leningradskiy
# Processing Record 41 of Set 6 | sangin
# Processing Record 42 of Set 6 | nha trang
# Processing Record 43 of Set 6 | sarkand
# Processing Record 44 of Set 6 | ilulissat
# Processing Record 45 of Set 6 | port lincoln
# Processing Record 46 of Set 6 | bras-panon
# Processing Record 47 of Set 6 | gondar
# Processing Record 48 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 6 | kaitangata
# Processing Record 50 of Set 6 | san patricio
# Processing Record 1 of Set 7 | vestmannaeyjar
# Processing Record 2 of Set 7 | zyryanka
# Processing Record 3 of Set 7 | komsomolskiy
# Processing Record 4 of Set 7 | iskateley
# Processing Record 5 of Set 7 | holme
# Processing Record 6 of Set 7 | katsuura
# Processing Record 7 of Set 7 | iqaluit
# Processing Record 8 of Set 7 | auburndale
# Processing Record 9 of Set 7 | kirkenaer
# Processing Record 10 of Set 7 | zarichne
# Processing Record 11 of Set 7 | udachnyy
# Processing Record 12 of Set 7 | isla mujeres
# Processing Record 13 of Set 7 | makakilo city
# Processing Record 14 of Set 7 | saint-philippe
# Processing Record 15 of Set 7 | vostok
# Processing Record 16 of Set 7 | miandrivazo
# Processing Record 17 of Set 7 | casper
# Processing Record 18 of Set 7 | lorengau
# Processing Record 19 of Set 7 | saint george
# Processing Record 20 of Set 7 | polunochnoye
# Processing Record 21 of Set 7 | moose factory
# Processing Record 22 of Set 7 | awjilah
# Processing Record 23 of Set 7 | salalah
# Processing Record 24 of Set 7 | paita
# Processing Record 25 of Set 7 | nemuro
# Processing Record 26 of Set 7 | roebourne
# Processing Record 27 of Set 7 | miramar
# Processing Record 28 of Set 7 | nueve de julio
# Processing Record 29 of Set 7 | palmer
# Processing Record 30 of Set 7 | padang
# Processing Record 31 of Set 7 | saint-francois
# Processing Record 32 of Set 7 | pucallpa
# Processing Record 33 of Set 7 | corinto
# Processing Record 34 of Set 7 | huarmey
# Processing Record 35 of Set 7 | glendive
# Processing Record 36 of Set 7 | namatanai
# Processing Record 37 of Set 7 | terra boa
# Processing Record 38 of Set 7 | umm lajj
# Processing Record 39 of Set 7 | barentu
# Processing Record 40 of Set 7 | fort dix
# Processing Record 41 of Set 7 | soyo
# Processing Record 42 of Set 7 | hede
# Processing Record 43 of Set 7 | touros
# Processing Record 44 of Set 7 | kostomuksha
# Processing Record 45 of Set 7 | trhove sviny
# Processing Record 46 of Set 7 | daurala
# Processing Record 47 of Set 7 | ola
# Processing Record 48 of Set 7 | vardo
# Processing Record 49 of Set 7 | garowe
# Processing Record 50 of Set 7 | port hedland
# Processing Record 1 of Set 8 | akdepe
# Processing Record 2 of Set 8 | havre-saint-pierre
# Processing Record 3 of Set 8 | gorom-gorom
# Processing Record 4 of Set 8 | gat
# Processing Record 5 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 8 | souillac
# Processing Record 7 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 8 | laguna
# Processing Record 9 of Set 8 | beyneu
# Processing Record 10 of Set 8 | zhigansk
# Processing Record 11 of Set 8 | merauke
# Processing Record 12 of Set 8 | cayenne
# Processing Record 13 of Set 8 | cabo san lucas
# Processing Record 14 of Set 8 | isangel
# Processing Record 15 of Set 8 | levelland
# Processing Record 16 of Set 8 | prince albert
# Processing Record 17 of Set 8 | roald
# Processing Record 18 of Set 8 | abonnema
# Processing Record 19 of Set 8 | margate
# Processing Record 20 of Set 8 | aklavik
# Processing Record 21 of Set 8 | san quintin
# Processing Record 22 of Set 8 | eydhafushi
# Processing Record 23 of Set 8 | burdur
# Processing Record 24 of Set 8 | dunedin
# Processing Record 25 of Set 8 | mersin
# Processing Record 26 of Set 8 | mattru
# Processing Record 27 of Set 8 | warrington
# Processing Record 28 of Set 8 | bozuyuk
# Processing Record 29 of Set 8 | tautira
# Processing Record 30 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 8 | bilibino
# Processing Record 32 of Set 8 | haapiti
# Processing Record 33 of Set 8 | shubarshi
# Processing Record 34 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 8 | sao sebastiao
# Processing Record 36 of Set 8 | whakatane
# Processing Record 37 of Set 8 | gumrak
# Processing Record 38 of Set 8 | fairbanks
# Processing Record 39 of Set 8 | galesong
# Processing Record 40 of Set 8 | bairiki
# Processing Record 41 of Set 8 | milingimbi
# City not found. Skipping...
# Processing Record 42 of Set 8 | nelson bay
# Processing Record 43 of Set 8 | marica
# Processing Record 44 of Set 8 | dambulla
# Processing Record 45 of Set 8 | naze
# Processing Record 46 of Set 8 | ustyuzhna
# Processing Record 47 of Set 8 | chara
# Processing Record 48 of Set 8 | medicine hat
# Processing Record 49 of Set 8 | mao
# Processing Record 50 of Set 8 | abu samrah
# Processing Record 1 of Set 9 | boende
# Processing Record 2 of Set 9 | nizhnyaya omka
# Processing Record 3 of Set 9 | kieta
# Processing Record 4 of Set 9 | kaseda
# Processing Record 5 of Set 9 | qasigiannguit
# Processing Record 6 of Set 9 | krasnyy oktyabr
# Processing Record 7 of Set 9 | luderitz
# Processing Record 8 of Set 9 | vuktyl
# Processing Record 9 of Set 9 | revda
# Processing Record 10 of Set 9 | muroto
# Processing Record 11 of Set 9 | bay roberts
# Processing Record 12 of Set 9 | easley
# Processing Record 13 of Set 9 | madimba
# Processing Record 14 of Set 9 | chabahar
# Processing Record 15 of Set 9 | rodental
# Processing Record 16 of Set 9 | san cristobal
# Processing Record 17 of Set 9 | riverton
# Processing Record 18 of Set 9 | paracuru
# Processing Record 19 of Set 9 | lakatoro
# Processing Record 20 of Set 9 | kudahuvadhoo
# Processing Record 21 of Set 9 | marsabit
# Processing Record 22 of Set 9 | koutiala
# Processing Record 23 of Set 9 | guerrero negro
# Processing Record 24 of Set 9 | mountain home
# Processing Record 25 of Set 9 | lata
# Processing Record 26 of Set 9 | acapulco
# Processing Record 27 of Set 9 | tolga
# Processing Record 28 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 29 of Set 9 | shenjiamen
# Processing Record 30 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 31 of Set 9 | caranavi
# Processing Record 32 of Set 9 | meulaboh
# Processing Record 33 of Set 9 | hoopstad
# Processing Record 34 of Set 9 | calexico
# Processing Record 35 of Set 9 | tabou
# Processing Record 36 of Set 9 | malazgirt
# Processing Record 37 of Set 9 | cedar city
# Processing Record 38 of Set 9 | kidal
# Processing Record 39 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 9 | khorramshahr
# Processing Record 41 of Set 9 | camana
# Processing Record 42 of Set 9 | hami
# Processing Record 43 of Set 9 | codrington
# Processing Record 44 of Set 9 | goderich
# Processing Record 45 of Set 9 | anadyr
# Processing Record 46 of Set 9 | ixtapa
# Processing Record 47 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 48 of Set 9 | berlevag
# Processing Record 49 of Set 9 | sovetskiy
# Processing Record 50 of Set 9 | watsa
# Processing Record 1 of Set 10 | shelburne
# Processing Record 2 of Set 10 | grandview
# Processing Record 3 of Set 10 | ayorou
# Processing Record 4 of Set 10 | popondetta
# Processing Record 5 of Set 10 | el alto
# Processing Record 6 of Set 10 | kununurra
# Processing Record 7 of Set 10 | suleja
# Processing Record 8 of Set 10 | assiniboia
# Processing Record 9 of Set 10 | wellington
# Processing Record 10 of Set 10 | turkmenabat
# Processing Record 11 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 10 | burnie
# Processing Record 13 of Set 10 | ancud
# Processing Record 14 of Set 10 | farafangana
# Processing Record 15 of Set 10 | aquiraz
# Processing Record 16 of Set 10 | kisangani
# Processing Record 17 of Set 10 | basoko
# Processing Record 18 of Set 10 | polyarnyy
# Processing Record 19 of Set 10 | lakes entrance
# Processing Record 20 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 21 of Set 10 | veraval
# Processing Record 22 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 10 | xining
# Processing Record 24 of Set 10 | gamba
# Processing Record 25 of Set 10 | shimoda
# Processing Record 26 of Set 10 | russell
# Processing Record 27 of Set 10 | port alberni
# Processing Record 28 of Set 10 | sabha
# Processing Record 29 of Set 10 | blagoyevo
# Processing Record 30 of Set 10 | leicester
# Processing Record 31 of Set 10 | pecos
# Processing Record 32 of Set 10 | chuari khas
# Processing Record 33 of Set 10 | jeremie
# Processing Record 34 of Set 10 | pundaguitan
# Processing Record 35 of Set 10 | zanjan
# Processing Record 36 of Set 10 | fort morgan
# Processing Record 37 of Set 10 | caronport
# Processing Record 38 of Set 10 | port-gentil
# Processing Record 39 of Set 10 | lake jackson
# Processing Record 40 of Set 10 | monrovia
# Processing Record 41 of Set 10 | pemangkat
# Processing Record 42 of Set 10 | ayna
# Processing Record 43 of Set 10 | bandarbeyla
# Processing Record 44 of Set 10 | ulaangom
# Processing Record 45 of Set 10 | bratsk
# Processing Record 46 of Set 10 | portland
# Processing Record 47 of Set 10 | norrtalje
# Processing Record 48 of Set 10 | kilindoni
# Processing Record 49 of Set 10 | anori
# Processing Record 50 of Set 10 | kitovo
# Processing Record 1 of Set 11 | saint anthony
# Processing Record 2 of Set 11 | arman
# Processing Record 3 of Set 11 | nabire
# Processing Record 4 of Set 11 | saint-paul
# Processing Record 5 of Set 11 | nampa
# Processing Record 6 of Set 11 | teguise
# Processing Record 7 of Set 11 | doos
# Processing Record 8 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 11 | maltahohe
# Processing Record 10 of Set 11 | belyy yar
# Processing Record 11 of Set 11 | kumbo
# Processing Record 12 of Set 11 | carahue
# Processing Record 13 of Set 11 | sirnak
# Processing Record 14 of Set 11 | campos belos
# Processing Record 15 of Set 11 | whitianga
# Processing Record 16 of Set 11 | kenora
# Processing Record 17 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 11 | sao filipe
# Processing Record 19 of Set 11 | gueret
# Processing Record 20 of Set 11 | fare
# Processing Record 21 of Set 11 | yabrud
# Processing Record 22 of Set 11 | axim
# Processing Record 23 of Set 11 | valparaiso
# Processing Record 24 of Set 11 | panaba
# Processing Record 25 of Set 11 | coracora
# Processing Record 26 of Set 11 | solnechnyy
# Processing Record 27 of Set 11 | marathon
# Processing Record 28 of Set 11 | hailar
# Processing Record 29 of Set 11 | port-de-bouc
# Processing Record 30 of Set 11 | havre
# Processing Record 31 of Set 11 | marshalltown
# Processing Record 32 of Set 11 | la libertad
# Processing Record 33 of Set 11 | anajatuba
# Processing Record 34 of Set 11 | batagay-alyta
# Processing Record 35 of Set 11 | kayasula
# Processing Record 36 of Set 11 | yumen
# Processing Record 37 of Set 11 | camacha
# Processing Record 38 of Set 11 | quatre cocos
# Processing Record 39 of Set 11 | nakamura
# Processing Record 40 of Set 11 | jalu
# Processing Record 41 of Set 11 | yurimaguas
# Processing Record 42 of Set 11 | maryborough
# Processing Record 43 of Set 11 | benin
# Processing Record 44 of Set 11 | santo amaro da imperatriz
# Processing Record 45 of Set 11 | skelleftea
# Processing Record 46 of Set 11 | oktyabrskiy
# Processing Record 47 of Set 11 | telenesti
# Processing Record 48 of Set 11 | japura
# Processing Record 49 of Set 11 | jonesboro
# Processing Record 50 of Set 11 | carutapera
# Processing Record 1 of Set 12 | okhotsk
# Processing Record 2 of Set 12 | jodhpur
# Processing Record 3 of Set 12 | caravelas
# Processing Record 4 of Set 12 | bima
# Processing Record 5 of Set 12 | lavrentiya
# Processing Record 6 of Set 12 | kunming
# Processing Record 7 of Set 12 | ndjole
# Processing Record 8 of Set 12 | waingapu
# Processing Record 9 of Set 12 | uvinza
# Processing Record 10 of Set 12 | nizhniy tsasuchey
# Processing Record 11 of Set 12 | champerico
# Processing Record 12 of Set 12 | constitucion
# Processing Record 13 of Set 12 | manwath
# City not found. Skipping...
# Processing Record 14 of Set 12 | angoram
# Processing Record 15 of Set 12 | linjiang
# Processing Record 16 of Set 12 | moju
# Processing Record 17 of Set 12 | tura
# Processing Record 18 of Set 12 | trinidad
# Processing Record 19 of Set 12 | beira
# Processing Record 20 of Set 12 | cairns
# Processing Record 21 of Set 12 | krasnoye
# Processing Record 22 of Set 12 | hamilton
# Processing Record 23 of Set 12 | krutikha
# Processing Record 24 of Set 12 | semey
# Processing Record 25 of Set 12 | hambantota
# Processing Record 26 of Set 12 | kayerkan
# Processing Record 27 of Set 12 | poum
# Processing Record 28 of Set 12 | jackson
# Processing Record 29 of Set 12 | tshikapa
# Processing Record 30 of Set 12 | ca mau
# Processing Record 31 of Set 12 | ballina
# Processing Record 32 of Set 12 | lardos
# Processing Record 33 of Set 12 | cap malheureux
# Processing Record 34 of Set 12 | houston
# Processing Record 35 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 12 | dongsheng
# Processing Record 37 of Set 12 | harper
# Processing Record 38 of Set 12 | progreso
# Processing Record 39 of Set 12 | ulladulla
# Processing Record 40 of Set 12 | petrovsk-zabaykalskiy
# Processing Record 41 of Set 12 | smalininkai
# Processing Record 42 of Set 12 | aksarayskiy
# Processing Record 43 of Set 12 | barinas
# Processing Record 44 of Set 12 | yenagoa
# Processing Record 45 of Set 12 | lahaina
# Processing Record 46 of Set 12 | heilbron
# Processing Record 47 of Set 12 | jaciara
# Processing Record 48 of Set 12 | otane
# Processing Record 49 of Set 12 | sao joao da barra
# Processing Record 50 of Set 12 | bahia blanca
# Processing Record 1 of Set 13 | zaozhuang
# Processing Record 2 of Set 13 | la rioja
# Processing Record 3 of Set 13 | ambad
# Processing Record 4 of Set 13 | gryazovets
# Processing Record 5 of Set 13 | marawi
# Processing Record 6 of Set 13 | vallenar
# Processing Record 7 of Set 13 | manzhouli
# Processing Record 8 of Set 13 | rovaniemi
# Processing Record 9 of Set 13 | jishou
# Processing Record 10 of Set 13 | garmsar
# Processing Record 11 of Set 13 | dubrovnik
# Processing Record 12 of Set 13 | faya
# Processing Record 13 of Set 13 | ustynivka
# Processing Record 14 of Set 13 | dzaoudzi
# Processing Record 15 of Set 13 | sechura
# Processing Record 16 of Set 13 | asfi
# Processing Record 17 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 18 of Set 13 | kloulklubed
# Processing Record 19 of Set 13 | siocon
# Processing Record 20 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 21 of Set 13 | los llanos de aridane
# Processing Record 22 of Set 13 | merzifon
# Processing Record 23 of Set 13 | warmbad
# Processing Record 24 of Set 13 | college
# Processing Record 25 of Set 13 | auki
# Processing Record 26 of Set 13 | danielskuil
# Processing Record 27 of Set 13 | puerto penasco
# Processing Record 28 of Set 13 | saint-augustin
# Processing Record 29 of Set 13 | petrinja
# Processing Record 30 of Set 13 | raudeberg
# Processing Record 31 of Set 13 | bambanglipuro
# Processing Record 32 of Set 13 | kajaani
# Processing Record 33 of Set 13 | dubovskoye
# Processing Record 34 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 35 of Set 13 | newton
# Processing Record 36 of Set 13 | rampur hat
# Processing Record 37 of Set 13 | kutum
# Processing Record 38 of Set 13 | murmashi
# Processing Record 39 of Set 13 | nhulunbuy
# Processing Record 40 of Set 13 | wyndham
# Processing Record 41 of Set 13 | udaipura
# Processing Record 42 of Set 13 | prieska
# Processing Record 43 of Set 13 | ayr
# Processing Record 44 of Set 13 | bassar
# Processing Record 45 of Set 13 | praya
# Processing Record 46 of Set 13 | gandajika
# Processing Record 47 of Set 13 | cabedelo
# Processing Record 48 of Set 13 | torrevieja
# Processing Record 49 of Set 13 | mackenzie
# Processing Record 50 of Set 13 | ndola
# Processing Record 1 of Set 14 | constantine
# Processing Record 2 of Set 14 | iranshahr
# Processing Record 3 of Set 14 | nalut
# Processing Record 4 of Set 14 | rafai
# Processing Record 5 of Set 14 | mabaruma
# Processing Record 6 of Set 14 | colomi
# Processing Record 7 of Set 14 | el reno
# Processing Record 8 of Set 14 | vao
# Processing Record 9 of Set 14 | sao gabriel da cachoeira
# Processing Record 10 of Set 14 | marana
# Processing Record 11 of Set 14 | avera
# Processing Record 12 of Set 14 | darnah
# Processing Record 13 of Set 14 | dalnerechensk
# Processing Record 14 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 14 | araouane
# Processing Record 16 of Set 14 | miranorte
# City not found. Skipping...
# Processing Record 17 of Set 14 | freeport
# Processing Record 18 of Set 14 | belem de sao francisco
# Processing Record 19 of Set 14 | richards bay
# Processing Record 20 of Set 14 | springfield
# Processing Record 21 of Set 14 | greenville
# Processing Record 22 of Set 14 | zakamensk
# Processing Record 23 of Set 14 | tucurui
# Processing Record 24 of Set 14 | locri
# Processing Record 25 of Set 14 | luba
# Processing Record 26 of Set 14 | ilo
# Processing Record 27 of Set 14 | ukiah
# Processing Record 28 of Set 14 | lasa
# Processing Record 29 of Set 14 | deputatskiy
# Processing Record 30 of Set 14 | innisfail
# Processing Record 31 of Set 14 | san antonio
# Processing Record 32 of Set 14 | mosalsk
# Processing Record 33 of Set 14 | kalaleh
# Processing Record 34 of Set 14 | zhaotong
# Processing Record 35 of Set 14 | puerto plata
# Processing Record 36 of Set 14 | strelka
# Processing Record 37 of Set 14 | umm kaddadah
# Processing Record 38 of Set 14 | dong hoi
# Processing Record 39 of Set 14 | martapura
# Processing Record 40 of Set 14 | sinnamary
# Processing Record 41 of Set 14 | svetlogorsk
# Processing Record 42 of Set 14 | miles city
# Processing Record 43 of Set 14 | zaozerne
# Processing Record 44 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 14 | port hardy
# Processing Record 46 of Set 14 | bakchar
# Processing Record 47 of Set 14 | sitka
# Processing Record 48 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 49 of Set 14 | bathsheba
# Processing Record 50 of Set 14 | adre
# Processing Record 1 of Set 15 | chapleau
# Processing Record 2 of Set 15 | west wendover
# Processing Record 3 of Set 15 | mangrol
# Processing Record 4 of Set 15 | vale
# Processing Record 5 of Set 15 | clovis
# Processing Record 6 of Set 15 | alofi
# Processing Record 7 of Set 15 | nioro
# Processing Record 8 of Set 15 | imeni poliny osipenko
# Processing Record 9 of Set 15 | morro bay
# Processing Record 10 of Set 15 | san jose
# Processing Record 11 of Set 15 | praia da vitoria
# Processing Record 12 of Set 15 | biggar
# Processing Record 13 of Set 15 | bin qirdan
# Processing Record 14 of Set 15 | dhuburi
# Processing Record 15 of Set 15 | port hawkesbury
# Processing Record 16 of Set 15 | purranque
# Processing Record 17 of Set 15 | pacifica
# Processing Record 18 of Set 15 | beatrice
# Processing Record 19 of Set 15 | thinadhoo
# Processing Record 20 of Set 15 | viru
# Processing Record 21 of Set 15 | biak
# Processing Record 22 of Set 15 | iwaki
# Processing Record 23 of Set 15 | svetlaya
# Processing Record 24 of Set 15 | impfondo
# Processing Record 25 of Set 15 | malatya
# Processing Record 26 of Set 15 | kargopol
# Processing Record 27 of Set 15 | mogadishu
# Processing Record 28 of Set 15 | yerbogachen
# Processing Record 29 of Set 15 | ajdabiya
# Processing Record 30 of Set 15 | bone
# Processing Record 31 of Set 15 | ankazobe
# Processing Record 32 of Set 15 | la grande
# Processing Record 33 of Set 15 | san jeronimo
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 680

# %%
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0        lompoc      US  2022-05-13 20:59:03  34.6391 -120.4579     93.34
# 1     jamestown      US  2022-05-13 20:55:05  42.0970  -79.2353     78.44
# 2    bredasdorp      ZA  2022-05-13 21:00:04 -34.5322   20.0403     55.36
# 3       ushuaia      AR  2022-05-13 20:56:02 -54.8000  -68.3000     42.46
# 4         vaini      TO  2022-05-13 21:00:05 -21.2000 -175.2000     74.84
# 5  punta arenas      CL  2022-05-13 21:00:05 -53.1500  -70.9167     44.11
# 6       mataura      NZ  2022-05-13 21:00:06 -46.1927  168.8643     52.48
# 7      tasiilaq      GL  2022-05-13 21:00:08  65.6145  -37.6368     24.89
# 8     carnarvon      AU  2022-05-13 21:00:09 -24.8667  113.6333     64.58
# 9   juan lacaze      UY  2022-05-13 21:00:10 -34.4342  -57.4381     62.11
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        53           0       21.99           clear sky
# 1        50          75       14.97       broken clouds
# 2        74          79        7.20       broken clouds
# 3        93          75       10.36       broken clouds
# 4        65          39       18.34          light rain
# 5        70         100        8.28     overcast clouds
# 6        97         100        2.51     overcast clouds
# 7        66          42        1.57    scattered clouds
# 8        62           0       19.39           clear sky
# 9        64         100        4.05     overcast clouds

# %%
#Save the new DataFrame as a CSV file

challenge_city_data_df.to_csv(path_or_buf='Weather_Database/WeatherPy_Database.csv', index_label='City_ID')
